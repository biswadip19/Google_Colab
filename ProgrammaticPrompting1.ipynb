# %% [markdown]
# <a href="https://colab.research.google.com/github/biswadip19/Google_Colab/blob/main/ProgrammaticPrompting1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key

# %%
from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o",
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content


messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# Certainly! Swapping keys and values in a dictionary is a common task. In functional programming, we strive for immutability and purity, so we'll create a new dictionary rather than modifying the original. Here's a pure function in Python to accomplish this:
#
# ```python
# def swap_keys_values(d):
#     return {value: key for key, value in d.items()}
#
# # Example usage
# original_dict = {'a': 1, 'b': 2, 'c': 3}
# swapped_dict = swap_keys_values(original_dict)
# print(swapped_dict)  # Output: {1: 'a', 2: 'b', 3: 'c'}
# ```
#
# ### Notes:
# 1. **Unique Values**: This function assumes that the values in the original dictionary are unique. If there are duplicate values, they will overwrite each other, and you will lose information.
# 2. **Immutable Operation**: The function doesn't modify the original dictionary `d` but returns a new dictionary with swapped keys and values.
# 3. **Efficiency**: This implementation is efficient and concise, utilizing Python’s dictionary comprehension.
#
# ...
